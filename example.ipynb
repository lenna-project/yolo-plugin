# %%
# %pip install numpy
# %pip install .
# Out:
# Requirement already satisfied: numpy in ./.venv/lib/python3.8/site-packages (1.22.0)
# Note: you may need to restart the kernel to use updated packages.
# Processing /home/chriamue/workspace/lenna-project/yolo-plugin
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Building wheels for collected packages: lenna-yolo-plugin
#   Building wheel for lenna-yolo-plugin (PEP 517) ... done
#   Created wheel for lenna-yolo-plugin: filename=lenna_yolo_plugin-0.1.0-cp38-cp38-linux_x86_64.whl size=64276081 sha256=674807f6bafbc3b44af8ec0ed4133a6ba84d5124aa095e699bea2f8a96ca8dfd
#   Stored in directory: /home/chriamue/.cache/pip/wheels/53/24/3d/7b0138ed55268692f3cbf096d758fa2297b67232ae63766db5
# Successfully built lenna-yolo-plugin
# Installing collected packages: lenna-yolo-plugin
#   Attempting uninstall: lenna-yolo-plugin
#     Found existing installation: lenna-yolo-plugin 0.1.0
#     Uninstalling lenna-yolo-plugin-0.1.0:
#       Successfully uninstalled lenna-yolo-plugin-0.1.0
# Successfully installed lenna-yolo-plugin-0.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image
from numpy import asarray
import lenna_yolo_plugin

# %%
image = Image.open("assets/dog.jpg")
img = asarray(image)
print(img.shape)
# Out:
# (576, 768, 3)

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=768x576 at 0x7F9D184F7B20>

# %%
config = lenna_yolo_plugin.default_config()

# %%
processed = lenna_yolo_plugin.process(config, img)
print(processed.shape)
processed_img = Image.fromarray(processed, 'RGB')
processed_img
# Out:
# (576, 768, 3)
# <PIL.Image.Image image mode=RGB size=768x576 at 0x7F9D1AD63E80>
